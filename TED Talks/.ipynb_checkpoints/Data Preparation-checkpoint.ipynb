# %%
import os
import pandas as pd
from tqdm.auto import tqdm
import re
import pickle
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
import time, datetime

tqdm.pandas()

def timestamp():
    ts = time.time()
    st = datetime.datetime.fromtimestamp(ts).strftime('%H:%M:%S:')
    return st


DIRECTORY = 'E:/Scrapped-Data/TED-Talks'
print(timestamp(), 'Libraries Imported')
# Out:
# Using TensorFlow backend.
# 20:42:20: Libraries Imported

# %%
NOT_WORDS_REGEX = re.compile(r"[^a-zA-Z]")
EXTRAWHITESPACES_REGEX = re.compile(r"\s+")

data = pd.read_csv(DIRECTORY+'/transcripts.csv')['transcript'].progress_apply(lambda x : EXTRAWHITESPACES_REGEX.sub(' ',
                                                                                NOT_WORDS_REGEX.sub(' ', x))).values
# Out:
# HBox(children=(IntProgress(value=0, max=2467), HTML(value='')))

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
print(timestamp(), 'Tokenizer Trained')

# count_thres = 5
# low_count_words = [w for w,c in tqdm(tokenizer.word_counts.items()) if c < count_thres]
# for w in tqdm(low_count_words):
#     del tokenizer.word_index[w]
#     del tokenizer.word_docs[w]
#     del tokenizer.word_counts[w]
# print(timestamp(), 'Tokenizer Updated')

pickle.dump(tokenizer, open(DIRECTORY+'/Tokenizer.pkl', 'wb'))
print(timestamp(), 'Tokenizer Pickled')
# Out:
# 20:43:10: Tokenizer Trained
# 20:43:10: Tokenizer Pickled

# %%
sorted(tokenizer.word_counts.items(), key=lambda x: x[1])
# Out:
# [('frankincense', 1),
#  ('avon', 1),
#  ('snitterfield', 1),
#  ('industrialism', 1),
#  ('paneled', 1),
#  ('webber', 1),
#  ('azores', 1),
#  ('leno', 1),
#  ('januarys', 1),
#  ('recapitulation', 1),
#  ('garfunkel', 1),
#  ('accompanist', 1),
#  ('brunette', 1),
#  ('tanked', 1),
#  ('sliders', 1),
#  ('bulleting', 1),
#  ('underlining', 1),
#  ('screensful', 1),
#  ('microsofts', 1),
#  ('flopped', 1),
#  ('macworld', 1),
#  ('turtleneck', 1),
#  ('evita', 1),
#  ('woz', 1),
#  ('rhyming', 1),
#  ('sonos', 1),
#  ('macros', 1),
#  ('frankness', 1),
#  ('darned', 1),
#  ('pelletizing', 1),
#  ('odiously', 1),
#  ('pushers', 1),
#  ('sheridan', 1),
#  ('parkland', 1),
#  ('hotbeds', 1),
#  ('alosa', 1),
#  ('thoroughfares', 1),
#  ('littering', 1),
#  ('bellos', 1),
#  ('cached', 1),
#  ('zayed', 1),
#  ('ugandans', 1),
#  ('quintile', 1),
#  ('axises', 1),
#  ('mofo', 1),
#  ('verbalization', 1),
#  ('bandying', 1),
#  ('dumbfounded', 1),
#  ('blab', 1),
#  ('thoroughfare', 1),
#  ('starched', 1),
#  ('sleeved', 1),
#  ('niceties', 1),
#  ('anthropomorphizes', 1),
#  ('sexualizes', 1),
#  ('xenu', 1),
#  ('overlord', 1),
#  ('lamanite', 1),
#  ('backpedaled', 1),
#  ('modernists', 1),
#  ('subsume', 1),
#  ('recombined', 1),
#  ('indeterminate', 1),
#  ('kilter', 1),
#  ('microlouver', 1),
#  ('unprogrammed', 1),
#  ('indiscernible', 1),
#  ('processions', 1),
#  ('intermissions', 1),
#  ('unviable', 1),
#  ('doggerel', 1),
#  ('kilmer', 1),
#  ('symbolisms', 1),
#  ('ectosymbiont', 1),
#  ('petunia', 1),
#  ('bookstall', 1),
#  ('verbum', 1),
#  ('dei', 1),
#  ('sator', 1),
#  ('autem', 1),
#  ('christus', 1),
#  ('insincere', 1),
#  ('engulfing', 1),
#  ('saddleback', 1),
#  ('televangelist', 1),
#  ('tithing', 1),
#  ('crook', 1),
#  ('acrostic', 1),
#  ('stohr', 1),
#  ('kenaf', 1),
#  ('cappella', 1),
#  ('mkhonza', 1),
#  ('tembisa', 1),
#  ('heller', 1),
#  ('zolli', 1),
#  ('biloxi', 1),
#  ('rehabbing', 1),
#  ('calhouns', 1),
#  ('luebkeman', 1),
#  ('lingually', 1),
#  ('pipsqueak', 1),
#  ('pows', 1),
#  ('basra', 1),
#  ('occupier', 1),
#  ('martyrs', 1),
#  ('azzam', 1),
#  ('bitterer', 1),
#  ('amandla', 1),
#  ('niggas', 1),
#  ('camen', 1),
#  ('apkon', 1),
#  ('karoli', 1),
#  ('umbilication', 1),
#  ('scabbing', 1),
#  ('confluent', 1),
#  ('shitala', 1),
#  ('mata', 1),
#  ('heymann', 1),
#  ('hank', 1),
#  ('heretofore', 1),
#  ('antivirals', 1),
#  ('fluologists', 1),
#  ('patna', 1),
#  ('chording', 1),
#  ('screensaver', 1),
#  ('ilya', 1),
#  ('rescale', 1),
#  ('rsi', 1),
#  ('anticipates', 1),
#  ('worldwind', 1),
#  ('puppeteering', 1),
#  ('siggraph', 1),
#  ('hci', 1),
#  ('truancy', 1),
#  ('backhaul', 1),
#  ('backlighting', 1),
#  ('payrolls', 1),
#  ('geoculturally', 1),
#  ('constructionists', 1),
#  ('fingerboard', 1),
#  ('jascha', 1),
#  ('liszt', 1),
#  ('solified', 1),
#  ('fina', 1),
#  ('carbonized', 1),
#  ('kokonte', 1),
#  ('starchy', 1),
#  ('ecole', 1),
#  ('charbon', 1),
#  ('cit', 1),
#  ('instron', 1),
#  ('briquetted', 1),
#  ('lovegroves', 1),
#  ('blobism', 1),
#  ('impressionism', 1),
#  ('seductor', 1),
#  ('anish', 1),
#  ('kapoor', 1),
#  ('tessellation', 1),
#  ('millefiori', 1),
#  ('foodstuffs', 1),
#  ('interlocution', 1),
#  ('bernhardt', 1),
#  ('godly', 1),
#  ('superliquidity', 1),
#  ('killarney', 1),
#  ('cored', 1),
#  ('moroso', 1),
#  ('garners', 1),
#  ('aluminium', 1),
#  ('ccp', 1),
#  ('coventry', 1),
#  ('bentleys', 1),
#  ('effervescent', 1),
#  ('notting', 1),
#  ('interject', 1),
#  ('plasnet', 1),
#  ('contaminator', 1),
#  ('wankers', 1),
#  ('revell', 1),
#  ('limoges', 1),
#  ('gernot', 1),
#  ('oberfell', 1),
#  ('kifwebe', 1),
#  ('ragtag', 1),
#  ('brockhaus', 1),
#  ('multimedial', 1),
#  ('enforces', 1),
#  ('wikipedian', 1),
#  ('hoaxes', 1),
#  ('handpicking', 1),
#  ('disconnects', 1),
#  ('shutouts', 1),
#  ('twb', 1),
#  ('instantiation', 1),
#  ('hardbound', 1),
#  ('hypergeometric', 1),
#  ('nubs', 1),
#  ('mathml', 1),
#  ('propertized', 1),
#  ('creativecommons', 1),
#  ('opencourseware', 1),
#  ('plagiarized', 1),
#  ('ouder', 1),
#  ('entrust', 1),
#  ('thaimu', 1),
#  ('freetown', 1),
#  ('reasure', 1),
#  ('remitted', 1),
#  ('earthlink', 1),
#  ('subpar', 1),
#  ('unapproachable', 1),
#  ('scribbler', 1),
#  ('lotte', 1),
#  ('reiniger', 1),
#  ('brouhaha', 1),
#  ('rathergate', 1),
#  ('pvrs', 1),
#  ('interplast', 1),
#  ('banjos', 1),
#  ('snowdeal', 1),
#  ('grabowski', 1),
#  ('typepad', 1),
#  ('zhen', 1),
#  ('aggrandize', 1),
#  ('yearbooks', 1),
#  ('braid', 1),
#  ('vasopressin', 1),
#  ('squealing', 1),
#  ('pooki', 1),
#  ('twat', 1),
#  ('pooky', 1),
#  ('poochi', 1),
#  ('poopi', 1),
#  ('poopelu', 1),
#  ('pooninana', 1),
#  ('padepachetchki', 1),
#  ('piche', 1),
#  ('toadie', 1),
#  ('nishi', 1),
#  ('coochi', 1),
#  ('snorcher', 1),
#  ('cooter', 1),
#  ('labbe', 1),
#  ('seagelman', 1),
#  ('horsespot', 1),
#  ('mongo', 1),
#  ('ghoulie', 1),
#  ('knish', 1),
#  ('schmende', 1),
#  ('incested', 1),
#  ('islamabad', 1),
#  ('amiga', 1),
#  ('quasar', 1),
#  ('faithfulness', 1),
#  ('dispensation', 1),
#  ('porthole', 1),
#  ('glassful', 1),
#  ('glassfuls', 1),
#  ('bladdersful', 1),
#  ('iguanodon', 1),
#  ('cycad', 1),
#  ('ungraspable', 1),
#  ('solidest', 1),
#  ('quickened', 1),
#  ('worlders', 1),
#  ('scathing', 1),
#  ('doinyo', 1),
#  ('lengai', 1),
#  ('barchan', 1),
#  ('westerly', 1),
#  ('discomforting', 1),
#  ('reallys', 1),
#  ('unvarnished', 1),
#  ('blueness', 1),
#  ('caprylic', 1),
#  ('caproic', 1),
#  ('lorentz', 1),
#  ('austerely', 1),
#  ('moles', 1),
#  ('striders', 1),
#  ('imputing', 1),
#  ('godlike', 1),
#  ('lighthearted', 1),
#  ('postrel', 1),
#  ('venkatesh', 1),
#  ('vps', 1),
#  ('franchisees', 1),
#  ('merchandising', 1),
#  ('foreshadows', 1),
#  ('franchisee', 1),
#  ('entourages', 1),
#  ('niggers', 1),
#  ('psychophysicist', 1),
#  ('bedeviled', 1),
#  ('yiddish', 1),
#  ('vlasic', 1),
#  ('tomatoey', 1),
#  ('tartness', 1),
#  ('sourness', 1),
#  ('jacksonville', 1),
#  ('robusto', 1),
#  ('turmeric', 1),
#  ('paprika', 1),
#  ('aromatics', 1),
#  ('oxnard', 1),
#  ('deliriously', 1),
#  ('meatloaf', 1),
#  ('paraplegics', 1),
#  ('gingrich', 1),
#  ('vegetably', 1),
#  ('minerally', 1),
#  ('animally', 1),
#  ('langerman', 1),
#  ('ringo', 1),
#  ('anterograde', 1),
#  ('korsakoff', 1),
#  ('polyneuritic', 1),
#  ('dogbert', 1),
#  ('silkier', 1),
#  ('fruitcake', 1),
#  ('returnable', 1),
#  ('winging', 1),
#  ('gall', 1),
#  ('turgid', 1),
#  ('overrating', 1),
#  ('ardor', 1),
#  ('cowardly', 1),
#  ('longings', 1),
#  ('balsamic', 1),
#  ('dyi', 1),
#  ('bleu', 1),
#  ('subtracts', 1),
#  ('nagged', 1),
#  ('stonewashed', 1),
#  ('pareto', 1),
#  ('banting', 1),
#  ('vertes', 1),
#  ('guanidine', 1),
#  ('originating', 1),
#  ('sylvester', 1),
#  ('pathogenesis', 1),
#  ('attractants', 1),
#  ('foxhunting', 1),
#  ('valueless', 1),
#  ('vacillate', 1),
#  ('postponing', 1),
#  ('ironclad', 1),
#  ('treble', 1),
#  ('rhr', 1),
#  ('ly', 1),
#  ('geriatricians', 1),
#  ('proteolysis', 1),
#  ('gerontologists', 1),
#  ('telomerase', 1),
#  ('hydra', 1),
#  ('bishops', 1),
#  ('telecommunication', 1),
#  ('gonofone', 1),
#  ('ceremoniously', 1),
#  ('bejesus', 1),
#  ('absolution', 1),
#  ('peeves', 1),
#  ('middleclass', 1),
#  ('aurangabad', 1),
#  ('modularized', 1),
#  ('sarita', 1),
#  ('vucinic', 1),
#  ('bratislava', 1),
#  ('repayments', 1),
#  ('kirshin', 1),
#  ('tupolev', 1),
#  ('rehire', 1),
#  ('morningstar', 1),
#  ('doxa', 1),
#  ('unquestioned', 1),
#  ('polities', 1),
#  ('emeralds', 1),
#  ('accountabilities', 1),
#  ('enfranchised', 1),
#  ('carthorse', 1),
#  ('internationalist', 1),
#  ('embroiderers', 1),
#  ('conditionalities', 1),
#  ('reexamined', 1),
#  ('credibly', 1),
#  ('hotrods', 1),
#  ('joyrides', 1),
#  ('frogger', 1),
#  ('defendable', 1),
#  ('elan', 1),
#  ('carmack', 1),
#  ('naca', 1),
#  ('hadow', 1),
#  ('severnaya', 1),
#  ('zemlya', 1),
#  ('kink', 1),
#  ('mountaineer', 1),
#  ('messner', 1),
#  ('sawn', 1),
#  ('nutritionists', 1),
#  ('krasnoyarsk', 1),
#  ('krasair', 1),
#  ('deadpan', 1),
#  ('flattish', 1),
#  ('mittens', 1),
#  ('roughty', 1),
#  ('toughty', 1),
#  ('grizzled', 1),
#  ('pieties', 1),
#  ('fizzing', 1),
#  ('headier', 1),
#  ('crassest', 1),
#  ('reaps', 1),
#  ('uncoupled', 1),
#  ('struthers', 1),
#  ('outdoorsman', 1),
#  ('frackville', 1),
#  ('westley', 1),
#  ('modesto', 1),
#  ('nimby', 1),
#  ('wushan', 1),
#  ('yuyuan', 1),
#  ('holdout', 1),
#  ('dengzahoos', 1),
#  ('baosteel', 1),
#  ('cupolas', 1),
#  ('diptych', 1),
#  ('pairings', 1),
#  ('youngor', 1),
#  ('lunchrooms', 1),
#  ('coffeemakers', 1),
#  ('shored', 1),
#  ('katja', 1),
#  ('strategize', 1),
#  ('winnings', 1),
#  ('clavicle', 1),
#  ('layperson', 1),
#  ('imd', 1),
#  ('exd', 1),
#  ('farmyard', 1),
#  ('qrs', 1),
#  ('ventricular', 1),
#  ('quivers', 1),
#  ('indigestion', 1),
#  ('cadwell', 1),
#  ('mes', 1),
#  ('depolarizer', 1),
#  ('zaps', 1),
#  ('yousef', 1),
#  ('swears', 1),
#  ('auras', 1),
#  ('errant', 1),
#  ('burr', 1),
#  ('rns', 1),
#  ('transcranial', 1),
#  ('videoed', 1),
#  ('bated', 1),
#  ('disappointedly', 1),
#  ('acquitted', 1),
#  ('disrepute', 1),
#  ('illogically', 1),
#  ('debunkers', 1),
#  ('bunko', 1),
#  ('squads', 1),
#  ('naders', 1),
#  ('dowser', 1),
#  ('thc', 1),
#  ('puckerbrush', 1),
#  ('governorship', 1),
#  ('dismantles', 1),
#  ('altadena', 1),
#  ('instamatic', 1),
#  ('christiaan', 1),
#  ('telescopic', 1),
#  ('froggy', 1),
#  ('guadalupe', 1),
#  ('branchy', 1),
#  ('splotchy', 1),
#  ('puckered', 1),
#  ('clearwater', 1),
#  ('reversespeech', 1),
#  ('hedgerow', 1),
#  ('melua', 1),
#  ('norah', 1),
#  ('edgethat', 1),
#  ('wimax', 1),
#  ('cdma', 1),
#  ('mips', 1),
#  ('bankruptcies', 1),
#  ('ravenously', 1),
#  ('respirocyte', 1),
#  ('psychoacoustic', 1),
#  ('beamers', 1),
#  ('twinkies', 1),
#  ('farrell', 1),
#  ('archaeas', 1),
#  ('sociability', 1),
#  ('depraved', 1),
#  ('cladistic', 1),
#  ('niles', 1),
#  ('eldredge', 1),
#  ('cornets', 1),
#  ('cornet', 1),
#  ('sheller', 1),
#  ('ploughs', 1),
#  ('prophesized', 1),
#  ('hustler', 1),
#  ('springsteen', 1),
#  ('kony', 1),
#  ('mistreating', 1),
#  ('dv', 1),
#  ('coletta', 1),
#  ('workaholics', 1),
#  ('workafrolics', 1),
#  ('jewison', 1),
#  ('sherwin', 1),
#  ('kraus', 1),
#  ('flirts', 1),
#  ('lovin', 1),
#  ('chattin', 1),
#  ('hotdiggitydog', 1),
#  ('ditzy', 1),
#  ('eee', 1),
#  ('devolving', 1),
#  ('pepsico', 1),
#  ('conagra', 1),
#  ('hosinia', 1),
#  ('kibagendi', 1),
#  ('onsomu', 1),
#  ('wabenzi', 1),
#  ('perspired', 1),
#  ('langata', 1),
#  ('squatted', 1),
#  ('hungrily', 1),
#  ('sulay', 1),
#  ('montakaya', 1),
#  ('loggia', 1),
#  ('crud', 1),
#  ('gavea', 1),
#  ('beco', 1),
#  ('becos', 1),
#  ('toi', 1),
#  ('grillos', 1),
#  ('gecekondu', 1),
#  ('geeta', 1),
#  ('jiwa', 1),
#  ('sureka', 1),
#  ('gundi', 1),
#  ('muthama', 1),
#  ('cezinio', 1),
#  ('prefects', 1),
#  ('inroad', 1),
#  ('emmerich', 1),
#  ('positing', 1),
#  ('dharma', 1),
#  ('kaisut', 1),
#  ('curandero', 1),
#  ('caravanserai', 1),
#  ('qomolangma', 1),
#  ('cantonese', 1),
#  ('barasana', 1),
#  ('mythologically', 1),
#  ('exogamy', 1),
#  ('genealogies', 1),
#  ('perspicacious', 1),
#  ('duvalier', 1),
#  ('tonton', 1),
#  ('macoutes', 1),
#  ('vodoun', 1),
#  ('acolyte', 1),
#  ('voodooists', 1),
#  ('bloodstained', 1),
#  ('inculturated', 1),
#  ('rousseau', 1),
#  ('canard', 1),
#  ('asmat', 1),
#  ('kwagiulth', 1),
#  ('huxwhukw', 1),
#  ('dwelled', 1),
#  ('hamatsa', 1),
#  ('harmine', 1),
#  ('harmaline', 1),
#  ('psychotria', 1),
#  ('viridis', 1),
#  ('dimethyltryptamine', 1),
#  ('shultes', 1),
#  ('denatured', 1),
#  ('monoamine', 1),
#  ('oxidase', 1),
#  ('denatures', 1),
#  ('tryptamine', 1),
#  ('cofan', 1),
#  ('referable', 1),
#  ('stamens', 1),
#  ('silt', 1),
#  ('ethnocide', 1),
#  ('ascribed', 1),
#  ('panchen', 1),
#  ('polychromatic', 1),
#  ('blandly', 1),
#  ('narwhal', 1),
#  ('olayuk', 1),
#  ('sealskin', 1),
#  ('floes', 1),
#  ('nunavut', 1),
#  ('jokhang', 1),
#  ('jigme', 1),
#  ('sonam', 1),
#  ('tenzin', 1),
#  ('gyatso', 1),
#  ('auca', 1),
#  ('seismologists', 1),
#  ('blowguns', 1),
#  ('curare', 1),
#  ('paraquat', 1),
#  ('defoliating', 1),
#  ('dax', 1),
#  ('tora', 1),
#  ('insular', 1),
#  ('roper', 1),
#  ('retinue', 1),
#  ('gigayears', 1),
#  ('ouroboros', 1),
#  ('gastronomically', 1),
#  ('unifies', 1),
#  ('physique', 1),
#  ('cybertechnologies', 1),
#  ('relinquishment', 1),
#  ('pugwash', 1),
#  ('concertinaed', 1),
#  ('herblock', 1),
#  ('waned', 1),
#  ('successions', 1),
#  ('ominously', 1),
#  ('elapsed', 1),
#  ('farseeing', 1),
#  ('encases', 1),
#  ('chiefdom', 1),
#  ('decently', 1),
#  ('vibes', 1),
#  ('conduces', 1),
#  ('andwork', 1),
#  ('allegation', 1),
#  ('erring', 1),
#  ('rigatoni', 1),
#  ('cesspool', 1),
#  ('dobsonian', 1),
#  ('condescend', 1),
#  ('nhs', 1),
#  ('slavers', 1),
#  ('scram', 1),
#  ('unlikeable', 1),
#  ('maxine', 1),
#  ('curtsey', 1),
#  ('paulette', 1),
#  ('subside', 1),
#  ('fondling', 1),
#  ('majorettes', 1),
#  ('rodeos', 1),
#  ('jolene', 1),
#  ('hedeman', 1),
#  ('mealey', 1),
#  ('homsey', 1),
#  ('peppermint', 1),
#  ('endy', 1),
#  ('glibly', 1),
#  ('howtoons', 1),
#  ('dragotta', 1),
#  ('cheerios', 1),
#  ('hydrophobicity', 1),
#  ('hydrophylicity', 1),
#  ('radiolara', 1),
#  ('unicellular', 1),
#  ('ribosome', 1),
#  ('astigmatic', 1),
#  ('monomer', 1),
#  ('kulp', 1),
#  ('butow', 1),
#  ('neuman', 1),
#  ('templating', 1),
#  ('functionalizing', 1),
#  ('nanoclusters', 1),
#  ('segregate', 1),
#  ('cutters', 1),
#  ('excimer', 1),
#  ('electromagnetics', 1),
#  ('pobal', 1),
#  ('secondi', 1),
#  ('takoradi', 1),
#  ('soshanguve', 1),
#  ('fabbing', 1),
#  ('kernigan', 1),
#  ('pdps', 1),
#  ('minicomputers', 1),
#  ('minicomputer', 1),
#  ('gladiatorial', 1),
#  ('unhurried', 1),
#  ('busier', 1),
#  ('deceleration', 1),
#  ('enema', 1),
#  ('tantric', 1),
#  ('heartrending', 1),
#  ('decompress', 1),
#  ('bans', 1),
#  ('hothouse', 1),
#  ('walling', 1),
#  ('byword', 1),
#  ('gratuitously', 1),
#  ('litmus', 1),
#  ('stapled', 1),
#  ('amass', 1),
#  ('magaziner', 1),
#  ('bulks', 1),
#  ('gigging', 1),
#  ('incapacity', 1),
#  ('guerilla', 1),
#  ('kayonza', 1),
#  ('schroder', 1),
#  ('elsevier', 1),
#  ('myrmecologist', 1),
#  ('pinfish', 1),
#  ('antelopes', 1),
#  ('roundworm', 1),
#  ('impressionistic', 1),
#  ('prophages', 1),
#  ('eukaryota', 1),
#  ('endangerment', 1),
#  ('cataclysms', 1),
#  ('invisiblestanding', 1),
#  ('straddled', 1),
#  ('oligarchy', 1),
#  ('scorched', 1),
#  ('sandinista', 1),
#  ('somoza', 1),
#  ('molotovs', 1),
#  ('jenin', 1),
#  ('mostar', 1),
#  ('clouding', 1),
#  ('transkei', 1),
#  ('chechen', 1),
#  ('incurables', 1),
#  ('detox', 1),
#  ('defoliant', 1),
#  ('vietcong', 1),
#  ('dioxin', 1),
#  ('supplemental', 1),
#  ('kunduz', 1),
#  ('karbala', 1),
#  ('ashura', 1),
#  ('regal', 1),
#  ('finery', 1),
#  ('acclimatized', 1),
#  ('toolmaker', 1),
#  ('wuzzy', 1),
#  ('wuzzier', 1),
#  ('suckling', 1),
#  ('sapient', 1),
#  ('dappled', 1),
#  ('desolated', 1),
#  ('koons', 1),
#  ('spiff', 1),
#  ('memail', 1),
#  ('aeron', 1),
#  ('poil', 1),
#  ('amihotornot', 1),
#  ('cremains', 1),
#  ('ozzie', 1),
#  ('osborne', 1),
#  ('sacd', 1),
#  ('episcopalian', 1),
#  ('ornithology', 1),
#  ('biochemist', 1),
#  ('birdwatcher', 1),
#  ('hust', 1),
#  ('nirenberg', 1),
#  ('szilard', 1),
#  ('recombinant', 1),
#  ('photolithography', 1),
#  ('nimblegen', 1),
#  ('affymetrix', 1),
#  ('segs', 1),
#  ('predisposure', 1),
#  ('clio', 1),
#  ('incorporations', 1),
#  ('shigeo', 1),
#  ('fukuda', 1),
#  ('knowlton', 1),
#  ('shortz', 1),
#  ('cederquist', 1),
#  ('horseless', 1),
#  ('ibots', 1),
#  ('architected', 1),
#  ('conestoga', 1),
#  ('wilshire', 1),
#  ('postmaster', 1),
#  ('subliminally', 1),
#  ('aarp', 1),
#  ('dionysus', 1),
#  ('segway', 1),
#  ('hydride', 1),
#  ('desalinate', 1),
#  ('distiller', 1),
#  ('backstroke', 1),
#  ('restitching', 1),
#  ('namibiensis', 1),
#  ('bongos', 1),
#  ('elands', 1),
#  ('sumatran', 1),
#  ('dodos', 1),
#  ('aatcagggaccc', 1),
#  ('tacgggg', 1),
#  ('outlay', 1),
#  ('declarative', 1),
#  ('chippies', 1),
#  ('insurability', 1),
#  ('mll', 1),
#  ('aml', 1),
#  ('superexponential', 1),
#  ('ucsd', 1),
#  ('torrey', 1),
#  ('argentines', 1),
#  ('serfs', 1),
#  ('foment', 1),
#  ('seceding', 1),
#  ('tak', 1),
#  ('bregenz', 1),
#  ('monographs', 1),
#  ('arcadia', 1),
#  ('yoko', 1),
#  ('ono', 1),
#  ('representable', 1),
#  ('shunsho', 1),
#  ('turrell', 1),
#  ('retractable', 1),
#  ('recoupable', 1),
#  ('jee', 1),
#  ('gluttonous', 1),
#  ('shareable', 1),
#  ('scoping', 1),
#  ('beddington', 1),
#  ('flashfloods', 1),
#  ('morphic', 1),
#  ('copyleft', 1),
#  ('telecentro', 1),
#  ('lifestraw', 1),
#  ('lineal', 1),
#  ('calvino', 1),
#  ('ewan', 1),
#  ('concretizing', 1),
#  ('coherencies', 1),
#  ('penang', 1),
#  ('ioc', 1),
#  ('figuration', 1),
#  ('constructional', 1),
#  ('sonnier', 1),
#  ('shibuya', 1),
#  ('sausalito', 1),
#  ('pomona', 1),
#  ('occupiable', 1),
#  ('sculpturally', 1),
#  ('laugier', 1),
#  ('ecb', 1),
#  ('himmelblau', 1),
#  ('hooper', 1),
#  ('savoy', 1),
#  ('nobile', 1),
#  ('rusticated', 1),
#  ('stonework', 1),
#  ('plinth', 1),
#  ('infectiousness', 1),
#  ('irrationalisms', 1),
#  ('truisms', 1),
#  ('pygmalion', 1),
#  ('goschel', 1),
#  ('tirades', 1),
#  ('coupes', 1),
#  ('magnusson', 1),
#  ('iful', 1),
#  ('petrarchan', 1),
#  ('ooooo', 1),
#  ('bodoni', 1),
#  ('typographically', 1),
#  ('mappy', 1),
#  ('wowcharts', 1),
#  ('decorator', 1),
#  ('llewelyn', 1),
#  ('bowen', 1),
#  ('cooney', 1),
#  ('mestral', 1),
#  ('birkenstock', 1),
#  ('burrs', 1),
#  ('catseye', 1),
#  ('lustish', 1),
#  ('teabag', 1),
#  ('semaphore', 1),
#  ('semiotic', 1),
#  ('aggressor', 1),
#  ('iconoclastic', 1),
#  ('stux', 1),
#  ('durer', 1),
#  ('stieglitz', 1),
#  ('ghiberti', 1),
#  ('corot', 1),
#  ('valicia', 1),
#  ('jacynthe', 1),
#  ('scatology', 1),
#  ('mosaics', 1),
#  ('swatches', 1),
#  ('swatch', 1),
#  ('haystacks', 1),
#  ('smithson', 1),
#  ('earthworks', 1),
#  ('cartoonish', 1),
#  ('grimaldi', 1),
#  ('impersonated', 1),
#  ('adderall', 1),
#  ('anabolic', 1),
#  ('queasiness', 1),
#  ('modifiers', 1),
#  ('positional', 1),
#  ('unitary', 1),
#  ('bafflement', 1),
#  ('undiminished', 1),
#  ('voles', 1),
#  ('vole', 1),
#  ('bowman', 1),
#  ('mistaked', 1),
#  ('adapters', 1),
#  ('bioprocessing', 1),
#  ('seashell', 1),
#  ('tpa', 1),
#  ('slavishly', 1),
#  ('hairdo', 1),
#  ('slavish', 1),
#  ('geranium', 1),
#  ('knothole', 1),
#  ('brinker', 1),
#  ('diatom', 1),
#  ('mineralization', 1),
#  ('joanna', 1),
#  ('aizenberg', 1),
#  ('polycarbonates', 1),
#  ('tubercles', 1),
#  ('lotusan', 1),
#  ('quenching', 1),
#  ('chelate', 1),
#  ('rosner', 1),
#  ('sweeten', 1),
#  ('apparatuses', 1),
#  ('transposons', 1),
#  ('infective', 1),
#  ('methanococcus', 1),
#  ('jannaschii', 1),
#  ('statoil', 1),
#  ('repertoires', 1),
#  ('cellulases', 1),
#  ('macromedia', 1),
#  ('bane', 1),
#  ('bitforms', 1),
#  ('hairier', 1),
#  ('australopithecines', 1),
#  ('canopied', 1),
#  ('bidpedally', 1),
#  ('nhk', 1),
#  ('gona', 1),
#  ('harmonica', 1),
#  ('panhomoculture', 1),
#  ('foreshadowed', 1),
#  ('tuataras', 1),
#  ('shimmers', 1),
#  ('cycads', 1),
#  ('proteas', 1),
#  ('lusher', 1),
#  ('shrews', 1),
#  ('tenrecs', 1),
#  ('civets', 1),
#  ('walruses', 1),
#  ('stilt', 1),
#  ('tarsiers', 1),
#  ('spearers', 1),
#  ('smashers', 1),
#  ('flexes', 1),
#  ('spearer', 1),
#  ('hyperextending', 1),
#  ('anticlastic', 1),
#  ('catalano', 1),
#  ('spanwise', 1),
#  ('piezoelectronic', 1),
#  ('cavitate', 1),
#  ('arthropod', 1),
#  ('daisies', 1),
#  ('dogwoods', 1),
#  ('frisbees', 1),
#  ('sunbathers', 1),
#  ('gerda', 1),
#  ('snarl', 1),
#  ('hoots', 1),
#  ('cackles', 1),
#  ('growls', 1),
#  ...]

# %%
tokenizer = pickle.load(open(DIRECTORY+'/Tokenizer.pkl', 'rb'))

data = tokenizer.texts_to_sequences(tqdm(data))
print(timestamp(), 'Data Tokenized')

data = [item for sublist in tqdm(data) for item in sublist]
print(timestamp(), 'Token List Flattened', len(data))

print(len(tokenizer.word_counts))
# Out:
# HBox(children=(IntProgress(value=0, max=2467), HTML(value='')))
# 20:44:04: Data Tokenized
# HBox(children=(IntProgress(value=0, max=2467), HTML(value='')))
# 20:44:05: Token List Flattened 5205469
# 57445

# %%
train_len = 3 + 1
sequences = []
for i in tqdm(range(train_len, len(data)+1)):
    seq = data[i-train_len:i]
    sequences.append(seq)
print(timestamp(), 'Sequenced', len(sequences))
# Out:
# HBox(children=(IntProgress(value=0, max=5205466), HTML(value='')))
# 20:50:14: Sequenced 5205466

# %%
x = sequences[:, :-1]
y = sequences[:, -1]
vocab_size = len(tokenizer.word_counts)
y = to_categorical(y, num_classes=vocab_size+1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-b475b99a41f2> in <module>
#       2 y = sequences[:, -1]
#       3 vocab_size = len(tokenizer.word_counts)
# ----> 4 y = to_categorical(y, num_classes=vocab_size+1)
#
# D:\Users\Ritvik\Anaconda3\envs\datascience\lib\site-packages\keras\utils\np_utils.py in to_categorical(y, num_classes, dtype)
#      31         num_classes = np.max(y) + 1
#      32     n = y.shape[0]
# ---> 33     categorical = np.zeros((n, num_classes), dtype=dtype)
#      34     categorical[np.arange(n), y] = 1
#      35     output_shape = input_shape + (num_classes,)
#
# MemoryError:
